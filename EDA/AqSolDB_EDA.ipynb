# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
loc_aqsoldb = "../Code/Data/AqSolDB.csv"
db = pd.read_csv(loc_aqsoldb)

# %%
db.head()
# Out:
#     ID                                               Name  \
# 0  A-3         N,N,N-trimethyloctadecan-1-aminium bromide
# 1  A-4                           Benzo[cd]indol-2(1H)-one
# 2  A-5                               4-chlorobenzaldehyde
# 3  A-8  zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...
# 4  A-9  4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...
#
#                                                InChI  \
# 0  InChI=1S/C21H46N.BrH/c1-5-6-7-8-9-10-11-12-13-...
# 1  InChI=1S/C11H7NO/c13-11-8-5-1-3-7-4-2-6-9(12-1...
# 2        InChI=1S/C7H5ClO/c8-7-3-1-6(5-9)2-4-7/h1-5H
# 3  InChI=1S/2C23H22O3.Zn/c2*1-15(17-9-5-3-6-10-17...
# 4  InChI=1S/C25H30N2O4/c1-5-20(26(10-22-14-28-22)...
#
#                       InChIKey  \
# 0  SZEMGTQCPRNXEG-UHFFFAOYSA-M
# 1  GPYLCFQEKPUWLD-UHFFFAOYSA-N
# 2  AVPYQKSLYISFPO-UHFFFAOYSA-N
# 3  XTUPUYCJWKHGSW-UHFFFAOYSA-L
# 4  FAUAZXVRLVIARB-UHFFFAOYSA-N
#
#                                               SMILES  Solubility   SD  \
# ...

# %%
db.shape
# Out:
# (9982, 26)

# %%
db.iloc[:,:14].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9982 entries, 0 to 9981
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              9982 non-null   object
#  1   Name            9982 non-null   object
#  2   InChI           9982 non-null   object
#  3   InChIKey        9982 non-null   object
#  4   SMILES          9982 non-null   object
#  5   Solubility      9982 non-null   float64
#  6   SD              9982 non-null   float64
#  7   Ocurrences      9982 non-null   int64
#  8   Group           9982 non-null   object
#  9   MolWt           9982 non-null   float64
#  10  MolLogP         9982 non-null   float64
#  11  MolMR           9982 non-null   float64
#  12  HeavyAtomCount  9982 non-null   float64
#  13  NumHAcceptors   9982 non-null   float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
db.iloc[:,13:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9982 entries, 0 to 9981
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NumHAcceptors        9982 non-null   float64
#  1   NumHDonors           9982 non-null   float64
#  2   NumHeteroatoms       9982 non-null   float64
#  3   NumRotatableBonds    9982 non-null   float64
#  4   NumValenceElectrons  9982 non-null   float64
#  5   NumAromaticRings     9982 non-null   float64
#  6   NumSaturatedRings    9982 non-null   float64
#  7   NumAliphaticRings    9982 non-null   float64
#  8   RingCount            9982 non-null   float64
#  9   TPSA                 9982 non-null   float64
#  10  LabuteASA            9982 non-null   float64
#  11  BalabanJ             9982 non-null   float64
#  12  BertzCT              9982 non-null   float64
# dtypes: float64(13)
# memory usage: 1013.9 KB

# %%
db.describe().T
# Out:
#                       count        mean         std        min         25%  \
# Solubility           9982.0   -2.889909    2.368154 -13.171900   -4.326325
# SD                   9982.0    0.067449    0.234702   0.000000    0.000000
# Ocurrences           9982.0    1.378081    1.023476   1.000000    1.000000
# MolWt                9982.0  266.665946  184.179024   9.012000  162.276000
# MolLogP              9982.0    1.979167    3.517738 -40.873200    0.619750
# MolMR                9982.0   66.794594   46.523021   0.000000   40.602475
# HeavyAtomCount       9982.0   17.374674   12.241536   1.000000   11.000000
# NumHAcceptors        9982.0    3.486776    3.498203   0.000000    2.000000
# NumHDonors           9982.0    1.108595    1.488973   0.000000    0.000000
# NumHeteroatoms       9982.0    5.196955    4.736275   0.000000    3.000000
# NumRotatableBonds    9982.0    4.073031    5.646925   0.000000    1.000000
# ...

# %%
db['Group'].value_counts()
# Out:
# G1    7746
# G3    1182
# G5     636
# G2     235
# G4     183
# Name: Group, dtype: int64

# %%
db.columns
# Out:
# Index(['ID', 'Name', 'InChI', 'InChIKey', 'SMILES', 'Solubility', 'SD',
#        'Ocurrences', 'Group', 'MolWt', 'MolLogP', 'MolMR', 'HeavyAtomCount',
#        'NumHAcceptors', 'NumHDonors', 'NumHeteroatoms', 'NumRotatableBonds',
#        'NumValenceElectrons', 'NumAromaticRings', 'NumSaturatedRings',
#        'NumAliphaticRings', 'RingCount', 'TPSA', 'LabuteASA', 'BalabanJ',
#        'BertzCT'],
#       dtype='object')

# %%
# What is ocurrences??
db['Ocurrences'].value_counts()
# Out:
# 1     7746
# 2     1417
# 3      494
# 4      177
# 5       81
# 6       25
# 8       14
# 7       11
# 9        4
# 10       3
# 13       3
# 16       3
# 12       2
# 27       1
# 38       1
# Name: Ocurrences, dtype: int64

# %%
db[db['Ocurrences'] == 7]
# Out:
#           ID                                               Name  \
# 30      A-45                                      hydroxylamine
# 151    A-254                                calcium dihydroxide
# 226    A-382                                      triethylamine
# 459    A-808            5-methyl-2-(propan-2-yl)cyclohexan-1-ol
# 665   A-1156                                     ethenylbenzene
# 751   A-1308                                       butylbenzene
# 1180  A-2032  2,6-dibromo-4-[2-(3,5-dibromo-4-hydroxyphenyl)...
# 1241  A-2147                                    tetradecan-1-ol
# 1300  A-2257    1,2-bis(2-ethylhexyl) benzene-1,2-dicarboxylate
# 1983  A-3266                                     sodium formate
# 2733  A-4559  3-bromo-1-(3-chloropyridin-2-yl)-1H-pyrazole-5...
#
#                                                   InChI  \
# 30                           InChI=1S/H3NO/c1-2/h2H,1H2
# 151                  InChI=1S/Ca.2H2O/h;2*1H2/q+2;;/p-2
# ...

# %%
# db['Solubility'].hist(bins=50)
plt.hist(db['Solubility'], 50, alpha=0.9, histtype='bar', ec='black')
plt.tight_layout()

# %%
db['HeavyAtomCount'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
db.hist(bins=30, figsize=(15,14))
# Out:
# array([[<AxesSubplot:title={'center':'Solubility'}>,
#         <AxesSubplot:title={'center':'SD'}>,
#         <AxesSubplot:title={'center':'Ocurrences'}>,
#         <AxesSubplot:title={'center':'MolWt'}>],
#        [<AxesSubplot:title={'center':'MolLogP'}>,
#         <AxesSubplot:title={'center':'MolMR'}>,
#         <AxesSubplot:title={'center':'HeavyAtomCount'}>,
#         <AxesSubplot:title={'center':'NumHAcceptors'}>],
#        [<AxesSubplot:title={'center':'NumHDonors'}>,
#         <AxesSubplot:title={'center':'NumHeteroatoms'}>,
#         <AxesSubplot:title={'center':'NumRotatableBonds'}>,
#         <AxesSubplot:title={'center':'NumValenceElectrons'}>],
#        [<AxesSubplot:title={'center':'NumAromaticRings'}>,
#         <AxesSubplot:title={'center':'NumSaturatedRings'}>,
#         <AxesSubplot:title={'center':'NumAliphaticRings'}>,
#         <AxesSubplot:title={'center':'RingCount'}>],
#        [<AxesSubplot:title={'center':'TPSA'}>,
# ...

# %%
# smiles definitely need chemical standardisation
# can rdkit tell me if molecule is charged or not - wanna see distribution
# rdkit seems to work only on Python <3.8

# https://www.khanacademy.org/test-prep/mcat/organ-systems/the-respiratory-system/v/henry-s-law
