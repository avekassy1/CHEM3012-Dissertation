# %%
import pandas as pd
import numpy as np

# %%
loc_train = "../Data/EUROS_SLAS/train.csv"
df_train = pd.read_csv(loc_train)

# %%
df_train
# Out:
#               Id                                             smiles  \
# 0       EOS12286  Cc1nc(N2CCN(C(=O)Nc3ccc(F)cc3F)CC2)cc(-n2ccnc2)n1
# 1       EOS85869        CCN(CC)[C@H]1CCN(C(=O)Cc2nc(C(C)C)c(C)s2)C1
# 2       EOS85435                CNC(=O)CNC(=O)c1c(-n2cccc2)sc(C)c1C
# 3      EOS102302       CC(C)(C)c1ccc(CSc2cnn(C(C)(C)C)c(=O)c2Cl)cc1
# 4       EOS64213        CC[C@H](NC(=O)c1ccnc(-n2ccnc2)c1)c1ccccc1OC
# ...          ...                                                ...
# 70706   EOS37839        O=C(NCCCc1nc(=O)[nH][nH]1)[C@H]1CCC(F)(F)C1
# 70707    EOS2088          Cc1ccc(C(=O)NC2CCCC2)cc1S(=O)(=O)N1CCOCC1
# 70708   EOS10587      COCCN1CCC(CN(C)S(=O)(=O)c2cccc(C(F)(F)F)c2)C1
# 70709   EOS40533  O=C(Nc1ccc(F)cc1)NC1CCN(C(=O)Cc2cnn(-c3ccccc3)...
# 70710   EOS45458        COC[C@H](C)NC(=O)N1CCN(c2nnnn2-c2ccccc2)CC1
#
#        sol_category
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70711 entries, 0 to 70710
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            70711 non-null  object
#  1   smiles        70711 non-null  object
#  2   sol_category  70711 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ MB

# %%
df_train.describe()
# Out:
#        sol_category
# count  70711.000000
# mean       1.902179
# std        0.382076
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000

# %%
loc_example = "../Data/EUROS_SLAS/example_predictors.csv"
df_example = pd.read_csv(loc_example)

# %%
df_example.head()
# Out:
#         Id                                             smiles    SlogP  \
# 0  EOS2465           Cc1ccc(CN(C(=O)NCC(C)N2CCOCC2)C2CCCC2)s1  3.23142
# 1  EOS2466        O=C(NCC1CCCN(C(=O)Cc2cccs2)C1)c1ccc2nnnn2c1  1.39690
# 2  EOS2467  CO[C@@]12CC[C@H](Oc3ccccn3)C[C@@H]1N(Cc1cc(C3C...  3.27310
# 3  EOS2468            O=C(CC1C=CS(=O)(=O)C1)NCCCn1ncc2ccccc21  1.49100
# 4  EOS2469  Cc1cc2[nH]c(=O)[nH]c2c(NC(=O)c2ccc(S(C)(=O)=O)...  2.12884
#
#         SMR   LabuteASA    TPSA      AMW     ExactMW  NumLipinskiHBA  \
# 0  102.1077  154.878833   44.81  365.543  365.213698               5
# 1  100.4422  159.722714   92.49  384.465  384.136845               8
# 2  101.6217  159.819085   63.27  368.481  368.221226               6
# 3   88.3935  134.646129   81.06  333.413  333.114712               6
# 4   95.8984  143.557043  111.89  359.407  359.093977               7
#
#    NumLipinskiHBD  ...  VABC Volume Descriptor  Largest Chain  \
# ...

# %%
print(df_example.shape)
print()
print(df_example.columns)
# Out:
# (101018, 42)
#
# Index(['Id', 'smiles', 'SlogP', 'SMR', 'LabuteASA', 'TPSA', 'AMW', 'ExactMW',
#        'NumLipinskiHBA', 'NumLipinskiHBD', 'NumRotatableBonds', 'NumHBD',
#        'NumHBA', 'NumAmideBonds', 'NumHeteroAtoms', 'NumHeavyAtoms',
#        'NumAtoms', 'NumStereocenters', 'NumUnspecifiedStereocenters',
#        'NumRings', 'NumAromaticRings', 'NumSaturatedRings',
#        'NumAliphaticRings', 'NumAromaticHeterocycles',
#        'NumSaturatedHeterocycles', 'NumAliphaticHeterocycles',
#        'NumAromaticCarbocycles', 'NumSaturatedCarbocycles',
#        'NumAliphaticCarbocycles', 'FractionCSP3', 'HallKierAlpha',
#        'Eccentric Connectivity Index', 'VABC Volume Descriptor',
#        'Largest Chain', 'Largest Pi Chain', 'Petitjean Number',
#        'Lipinski's Rule of Five', 'Topological Polar Surface Area',
#        'Vertex adjacency information magnitude', 'XLogP', 'Zagreb Index',
#        'Rotatable Bonds Count (non terminal)'],
#       dtype='object')

# %%
df_example.describe().T
# Out:
#                                            count          mean           std  \
# SlogP                                   101018.0      2.273606  9.494253e-01
# SMR                                     101018.0     91.600738  1.608397e+01
# LabuteASA                               101018.0    142.576908  2.416289e+01
# TPSA                                    101018.0     71.699048  2.171606e+01
# AMW                                     101018.0    342.428886  5.861147e+01
# ExactMW                                 101018.0    342.099965  5.855453e+01
# NumLipinskiHBA                          101018.0      6.037518  1.612094e+00
# NumLipinskiHBD                          101018.0      1.091885  9.377991e-01
# NumRotatableBonds                       101018.0      4.604120  1.833458e+00
# NumHBD                                  101018.0      1.027371  8.430569e-01
# NumHBA                                  101018.0      4.818884  1.534353e+00
# ...

# %%
df_example.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101018 entries, 0 to 101017
# Data columns (total 42 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Id                                      101018 non-null  object
#  1   smiles                                  101011 non-null  object
#  2   SlogP                                   101018 non-null  float64
#  3   SMR                                     101018 non-null  float64
#  4   LabuteASA                               101018 non-null  float64
#  5   TPSA                                    101018 non-null  float64
#  6   AMW                                     101018 non-null  float64
#  7   ExactMW                                 101018 non-null  float64
#  8   NumLipinskiHBA                          101018 non-null  int64
#  9   NumLipinskiHBD                          101018 non-null  int64
# ...

# %%
# Tomorrow build quick ML with example predictors
# Merge train set and example set on compound ID
# Great project to learn metrics for classification - confusion matrix, area under the curve
